# %% [markdown]
# # Lesson 05 · Trap 1: out-of-order execution
#
# The author ran cell 2 first, then cell 1, then cell 3. Run top-to-bottom and it fails.

# %%
# cell 1 - USES total (auth ran cell 2 first interactively)
print('average price:', total / len(prices))

# %%
# cell 2 - DEFINES prices and total
prices = [10, 20, 30]
total = sum(prices)
print('total:', total)

# %%
# cell 3
print('count:', len(prices))
